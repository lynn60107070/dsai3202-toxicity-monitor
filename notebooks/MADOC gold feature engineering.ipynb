# %% [markdown]
# ## Load Silver data

# %%
spark.conf.set(
    "fs.azure.account.key.toxicitylake7032.dfs.core.windows.net",
    "DJ khaled anotha one keys keys keyss"
)

# %%
from pyspark.sql import functions as F

silver_path = "abfss://lakehouse@toxicitylake7032.dfs.core.windows.net/silver/reddit/"

df_silver = spark.read.parquet(silver_path)

df_silver.printSchema()
df_silver.show(5, truncate=False)
# Out:
# root
#  |-- post_id: string (nullable = true)
#  |-- publish_date: long (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- parent_id: string (nullable = true)
#  |-- parent_user_id: string (nullable = true)
#  |-- content: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- language: string (nullable = true)
#  |-- interaction_type: string (nullable = true)
#  |-- platform: string (nullable = true)
#  |-- community: string (nullable = true)
#  |-- strict_filter: integer (nullable = true)
#  |-- sentiment_vader: double (nullable = true)
#  |-- sentiment_textblob: double (nullable = true)
#  |-- subjectivity_textblob: double (nullable = true)
#  |-- toxicity_toxigen: double (nullable = true)
#
# +------------------------------------+------------+------------------------------------+---------+--------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+--------+----------------+--------+-------------+-------------+---------------+-------------------+---------------------+---------------------+
# |post_id                             |publish_date|user_id                             |parent_id|parent_user_id|content                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |url                                                                                                     |language|interaction_type|platform|community    |strict_filter|sentiment_vader|sentiment_textblob |subjectivity_textblob|toxicity_toxigen     |
# +------------------------------------+------------+------------------------------------+---------+--------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+--------+----------------+--------+-------------+-------------+---------------+-------------------+---------------------+---------------------+
# |8b9bc303-7770-5d73-a2c6-948471830dee|1419283272  |3616d72b-c2a7-5bc5-be38-aec8a1df0159|NULL     |NULL          |First post ( ͡° ͜ʖ ͡°)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |https://www.youtube.com/watch?v=t5RLwgDCsm4                                                             |English |POST            |reddit  |CringeAnarchy|NULL         |0.0            |0.25               |0.3333333333333333   |7.487140828743577E-4 |
# |9d730ec8-b236-5d71-9009-c279acae556a|1419284471  |3616d72b-c2a7-5bc5-be38-aec8a1df0159|NULL     |NULL          |This subreddit was created today, and is currently under construction. In the meantime, feel free to beta-test the colored text fonts.----------------------\n\n**Font colors:**\n\n- `[Your Text here](#b0)` = **Your Text here**\n\n- `[Your Text here](#g0)` = [Your Text here](#g0)\n\n- `[Your Text here](#r0)` = [Your Text here](#r0)\n\n- `[Your Text here](#c0)` = [Your Text here](#c0)\n\n- `[Your Text here](#o0)` = [Your Text here](#o0)\n\n- `[Your Text here](#grey0)` = [Your Text here](#grey0)\n\n- `[Appears when upvoted](#gh0)` = [Appears when upvoted](#gh0)\n\n----------------------\n\n**Size Variations (Pattern applies to all colors):**\n\n- `[Your Text here](#g0)` = [Your Text here](#g0)\n\n- `[Your Text here](#g1)` = [Your Text here](#g1)\n\n- `[Your Text here](#g2)` = [Your Text here](#g2)\n\n- `[Your Text here](#g3)` = [Your Text here](#g3)\n\n----------------------\n\n**Other:**\n\n`Begin a line with ###### for the following effect:`\n\n######Fire text\n\n----------------------|http://www.reddit.com/r/CringeAnarchy/comments/2q3xhs/this_subreddit_was_created_today_and_is_currently/|English |POST            |reddit  |CringeAnarchy|NULL         |0.6486         |0.13333333333333333|0.4333333333333334   |7.288327906280756E-4 |
# |1e992558-022f-590d-a93d-5b2299c6b563|1419286027  |8266167b-90bd-5d66-b5c1-8af2d3948d48|NULL     |NULL          |Star Trek / Doctor Who Mashup...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |https://www.youtube.com/watch?v=uiyrIuotFFA                                                             |English |POST            |reddit  |CringeAnarchy|NULL         |0.0            |0.0                |0.0                  |0.0010561398230493069|
# |9d1389b7-c9a4-5b70-b3a5-1abb121dee47|1419286582  |40bfefc1-0f61-54a2-8852-b859772c6ce2|NULL     |NULL          |Pornstar freaks out because of hippies                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |http://efukt.com/21055_The_Trainwreck_of_all_Trainwrecks.html                                           |English |POST            |reddit  |CringeAnarchy|NULL         |-0.1027        |0.0                |0.0                  |0.6300032734870911   |
# |cc979e6a-27ba-588d-93a7-337d31784d3b|1419286821  |3506345b-51fb-5e0d-b8af-03f0c43756b9|NULL     |NULL          |"It's much easier for a woman to find a new man."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |https://www.youtube.com/watch?v=UReTtePcLlA                                                             |English |POST            |reddit  |CringeAnarchy|NULL         |0.4215         |0.16818181818181818|0.32727272727272727  |0.11877617985010147  |
# +------------------------------------+------------+------------------------------------+---------+--------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+--------+----------------+--------+-------------+-------------+---------------+-------------------+---------------------+---------------------+
# only showing top 5 rows

# %% [markdown]
# ## Filter + clean basic columns

# %%
df = (
    df_silver
    .filter(F.col("content").isNotNull() & (F.length("content") > 3))
    .withColumn("publish_ts", F.from_unixtime("publish_date").cast("timestamp"))
    .withColumn("publish_date_only", F.to_date("publish_ts"))
)

# %% [markdown]
# ## Feature Engineering

# %%
# length features:

df = (
    df
    .withColumn("content_length_chars", F.length("content"))
    .withColumn("content_length_words", F.size(F.split("content", r"\s+")))
)

# %%
# toxicity binary label:

df = df.withColumn(
    "toxicity_label",
    (F.col("toxicity_toxigen") >= 0.5).cast("int")
)

# %%
# sentiment bucket:

df = df.withColumn(
    "sentiment_bucket",
    F.when(F.col("sentiment_vader") <= -0.2, "negative")
     .when(F.col("sentiment_vader") >= 0.2, "positive")
     .otherwise("neutral")
)

# %%
# Risk Scoring:

df = df.withColumn(
    "risk_level",
    F.when(F.col("toxicity_label") == 1, "high")
     .when(F.col("strict_filter") == 1, "medium")
     .otherwise("low")
)

# %% [markdown]
# ## Save Gold layer to Data Lake

# %%
df_gold = df.select(
    "post_id",
    "user_id",
    "parent_id",
    "parent_user_id",
    "platform",
    "community",
    "interaction_type",
    "publish_ts",
    "publish_date_only",
    "content",
    "url",
    "sentiment_vader",
    "sentiment_textblob",
    "subjectivity_textblob",
    "toxicity_toxigen",
    "strict_filter",
    "content_length_chars",
    "content_length_words",
    "toxicity_label",
    "sentiment_bucket",
    "risk_level"
)

df_gold.show(5, truncate=False)
# Out:
# +------------------------------------+------------------------------------+---------+--------------+--------+-------------+----------------+-------------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+---------------+-------------------+---------------------+---------------------+-------------+--------------------+--------------------+--------------+----------------+----------+
# |post_id                             |user_id                             |parent_id|parent_user_id|platform|community    |interaction_type|publish_ts         |publish_date_only|content                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |url                                                                                                     |sentiment_vader|sentiment_textblob |subjectivity_textblob|toxicity_toxigen     |strict_filter|content_length_chars|content_length_words|toxicity_label|sentiment_bucket|risk_level|
# +------------------------------------+------------------------------------+---------+--------------+--------+-------------+----------------+-------------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+---------------+-------------------+---------------------+---------------------+-------------+--------------------+--------------------+--------------+----------------+----------+
# |8b9bc303-7770-5d73-a2c6-948471830dee|3616d72b-c2a7-5bc5-be38-aec8a1df0159|NULL     |NULL          |reddit  |CringeAnarchy|POST            |2014-12-22 21:21:12|2014-12-22       |First post ( ͡° ͜ʖ ͡°)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |https://www.youtube.com/watch?v=t5RLwgDCsm4                                                             |0.0            |0.25               |0.3333333333333333   |7.487140828743577E-4 |NULL         |22                  |6                   |0             |neutral         |low       |
# |9d730ec8-b236-5d71-9009-c279acae556a|3616d72b-c2a7-5bc5-be38-aec8a1df0159|NULL     |NULL          |reddit  |CringeAnarchy|POST            |2014-12-22 21:41:11|2014-12-22       |This subreddit was created today, and is currently under construction. In the meantime, feel free to beta-test the colored text fonts.----------------------\n\n**Font colors:**\n\n- `[Your Text here](#b0)` = **Your Text here**\n\n- `[Your Text here](#g0)` = [Your Text here](#g0)\n\n- `[Your Text here](#r0)` = [Your Text here](#r0)\n\n- `[Your Text here](#c0)` = [Your Text here](#c0)\n\n- `[Your Text here](#o0)` = [Your Text here](#o0)\n\n- `[Your Text here](#grey0)` = [Your Text here](#grey0)\n\n- `[Appears when upvoted](#gh0)` = [Appears when upvoted](#gh0)\n\n----------------------\n\n**Size Variations (Pattern applies to all colors):**\n\n- `[Your Text here](#g0)` = [Your Text here](#g0)\n\n- `[Your Text here](#g1)` = [Your Text here](#g1)\n\n- `[Your Text here](#g2)` = [Your Text here](#g2)\n\n- `[Your Text here](#g3)` = [Your Text here](#g3)\n\n----------------------\n\n**Other:**\n\n`Begin a line with ###### for the following effect:`\n\n######Fire text\n\n----------------------|http://www.reddit.com/r/CringeAnarchy/comments/2q3xhs/this_subreddit_was_created_today_and_is_currently/|0.6486         |0.13333333333333333|0.4333333333333334   |7.288327906280756E-4 |NULL         |961                 |133                 |0             |positive        |low       |
# |1e992558-022f-590d-a93d-5b2299c6b563|8266167b-90bd-5d66-b5c1-8af2d3948d48|NULL     |NULL          |reddit  |CringeAnarchy|POST            |2014-12-22 22:07:07|2014-12-22       |Star Trek / Doctor Who Mashup...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |https://www.youtube.com/watch?v=uiyrIuotFFA                                                             |0.0            |0.0                |0.0                  |0.0010561398230493069|NULL         |32                  |6                   |0             |neutral         |low       |
# |9d1389b7-c9a4-5b70-b3a5-1abb121dee47|40bfefc1-0f61-54a2-8852-b859772c6ce2|NULL     |NULL          |reddit  |CringeAnarchy|POST            |2014-12-22 22:16:22|2014-12-22       |Pornstar freaks out because of hippies                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |http://efukt.com/21055_The_Trainwreck_of_all_Trainwrecks.html                                           |-0.1027        |0.0                |0.0                  |0.6300032734870911   |NULL         |38                  |6                   |1             |neutral         |high      |
# |cc979e6a-27ba-588d-93a7-337d31784d3b|3506345b-51fb-5e0d-b8af-03f0c43756b9|NULL     |NULL          |reddit  |CringeAnarchy|POST            |2014-12-22 22:20:21|2014-12-22       |"It's much easier for a woman to find a new man."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |https://www.youtube.com/watch?v=UReTtePcLlA                                                             |0.4215         |0.16818181818181818|0.32727272727272727  |0.11877617985010147  |NULL         |49                  |11                  |0             |positive        |low       |
# +------------------------------------+------------------------------------+---------+--------------+--------+-------------+----------------+-------------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+---------------+-------------------+---------------------+---------------------+-------------+--------------------+--------------------+--------------+----------------+----------+
# only showing top 5 rows

# %%
df_silver.select("community").distinct().show()
# Out:
# +--------------+
# |     community|
# +--------------+
# | CringeAnarchy|
# |    MensRights|
# |greatawakening|
# | fatpeoplehate|
# +--------------+

# %%
spark.conf.set("spark.sql.files.ignoreCorruptFiles", "true")

# %%
gold_path = "abfss://lakehouse@toxicitylake7032.dfs.core.windows.net/gold/reddit_features"

df_gold.write.mode("overwrite").parquet(gold_path)

# %% [markdown]
# ## Daily aggregated table for Power BI graphs

# %%
df_daily = (
    df_gold.groupBy("publish_date_only", "community")
    .agg(
        F.count("*").alias("num_interactions"),
        F.avg("toxicity_toxigen").alias("avg_toxicity"),
        F.avg("toxicity_label").alias("toxicity_rate"),
    )
)

daily_path = "abfss://lakehouse@toxicitylake7032.dfs.core.windows.net/gold/reddit_daily_stats"

df_daily.write.mode("overwrite").parquet(daily_path)
